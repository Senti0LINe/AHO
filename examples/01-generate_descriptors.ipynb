# %% [markdown]
# This notebook is a tutorial for generating all molecular descriptors used in the paper *Towards Data-driven Design of Asymmetric Hydrogenation of Olefins: Database and Hierarchical Learning*

# %% [markdown]
# # Load dependence

# %%
import numpy as np
import pandas as pd
import glob,os
from ase import Atoms
from gendesc import generate2Ddesc,generate3Ddesc,getusidx,getmorganfp
from mlutils import process_desc,molformatconversion,maxminscale
from dscribe.descriptors import MBTR
from rdkit import Chem
from rdkit.Chem.rdMolDescriptors import GetMorganFingerprintAsBitVect

# %% [markdown]
# # Read data file

# %% [markdown]
# For demonstration, we just operate on 5 entries data here

# %%
df = pd.read_csv('./data/demo_data.csv',index_col=0)   ### 
re_smi = df['Reactant SMILES'].to_numpy()
pr_smi = df['Product SMILES'].to_numpy()
sol_smi = df['Solvent SMILES'].to_numpy()
cat_smi = df['Catalyst SMILES(RDKit)'].to_numpy()
press = df['Pressure/atm'].to_numpy().reshape(-1,1)
temp = df['Temperature/C'].to_numpy().reshape(-1,1)
s_c = df['S/C'].to_numpy().reshape(-1,1)
tag = df['ddG'].to_numpy().reshape(-1,1)
df
# Out:
#                   Reactant SMILES                    Product SMILES  \
# 1        CCOC(=O)/C=C(\C)c1ccccc1        CCOC(=O)C[C@@H](C)c1ccccc1
# 2     CON(C)C(=O)/C=C(\C)c1ccccc1     CON(C)C(=O)C[C@@H](C)c1ccccc1
# 3     CON(C)C(=O)/C=C(\C)c1ccccc1     CON(C)C(=O)C[C@@H](C)c1ccccc1
# 4  CON(C)C(=O)/C=C(\C)c1ccc(C)cc1  CON(C)C(=O)C[C@@H](C)c1ccc(C)cc1
# 5             C=C(CO)c1ccc(Cl)cc1           C[C@@H](CO)c1ccc(Cl)cc1
#
#   Solvent SMILES  Additive SMILES Metal  \
# 1          ClCCl              NaN    Ir
# 2             CO              NaN    Ir
# 3          ClCCl              NaN    Ir
# 4          ClCCl              NaN    Ir
# 5          ClCCl              NaN    Ir
#
#                                        Ligand SMILES  \
# 1  Cc1ccccc1P(c1ccccc1C)N1[C@H]2CC[C@H](C2)[C@@H]...
# 2  CC(C)(C)[C@H]1COC(C2=CCC[C@@]23CCC=C3P(c2ccccc...
# 3  CC(C)C[C@H]1COC(C2=CCC[C@@]23CCC=C3P(c2ccccc2)...
# 4  C1=C(C2=N[C@@H](Cc3ccccc3)CO2)[C@@]2(CC1)CCC=C...
# 5  C[C@@H]1OC=N[C@@H]1C(Cc1ccccc1)(Cc1ccccc1)OP(C...
#
#                               Catalyst SMILES(RDKit)  Axial tag  Pressure/atm  \
# 1  Cc1ccccc1P(c1ccccc1C)8->N1[C@H]2CC[C@H](C2)[C@...          0            49
# 2  CC(C)(C)[C@H]1COC(C2=CCC[C@@]23CCC=C3P(c2ccccc...          0            50
# 3  CC(C)C[C@H]1COC(C2=CCC[C@@]23CCC=C3P(c2ccccc2)...          0            50
# 4  C1=C(C2=N9->[C@@H](Cc3ccccc3)CO2)[C@@]2(CC1)CC...          0            50
# 5  C[C@@H]1OC=N9->[C@@H]1C(Cc1ccccc1)(Cc1ccccc1)O...          0            10
#
#    Temperature/C  S/C       ddG    ee
# 1             25  200  2.720953  0.98
# 2             25  100  0.240092  0.20
# 3             25   50  1.369995  0.82
# 4             25   50  2.477863  0.97
# 5            -20  200  1.383259  0.88

# %% [markdown]
# # Generate 3D geometries

# %% [markdown]
# We need generate 3D geometries for 3D descriptors. For convenience, we stored GFN0-xTB-generated geometries in "demo_geoms.csv". We convert them into ".sdf" and ".xyz" files

# %%
demo_smi_geoms_map = pd.read_csv('./data/demo_geoms.csv',index_col=0)

# %%
smiles_keys = list(demo_smi_geoms_map.keys())
if not os.path.exists('./data/geoms_demo/'):
    os.mkdir('./data/geoms_demo/')
for idx,tmp_key in enumerate(smiles_keys):
    try:
        geoms_list = eval(demo_smi_geoms_map[tmp_key][0])[1].split('\n')
    except:
        geoms_list = [tmp_item.strip() for tmp_item in eval(demo_smi_geoms_map[tmp_key][0])[1]]
    if tmp_key in re_smi:
        tmp_type = 'react'
    elif tmp_key in pr_smi:
        tmp_type = 'prod'
    elif tmp_key in sol_smi:
        tmp_type = 'sol'
    elif tmp_key in cat_smi:
        tmp_type = 'cat'
    geoms_list[1] = '%s %s'%(tmp_key,tmp_type)
    geoms_string = '\n'.join(geoms_list)
    with open('./data/geoms_demo/geom_%d.xyz'%idx,'w') as fw:
        fw.writelines(geoms_string)
    molformatconversion('./data/geoms_demo/geom_%d.xyz'%idx,'./data/geoms_demo/geom_%d.sdf'%idx,'xyz','sdf')
# Out:
# 1 molecules converted
# 1 molecules converted
# 1 molecules converted
# 1 molecules converted
# 1 molecules converted
# 1 molecules converted
# 1 molecules converted
# 1 molecules converted
# 1 molecules converted
# 1 molecules converted
# 1 molecules converted
# 1 molecules converted
# 1 molecules converted
# 1 molecules converted
# 1 molecules converted

# %% [markdown]
# # Generate 2D/3D descriptor map

# %% [markdown]
# *generate2Ddesc*,*generate3Ddesc* modules in *gendesc* can be used to generate 2D descriptors including **MolecularFingerprint (MF)**, **200 (or 208) molecular descriptors built-in RDKit**, and **molecular descriptors built-in Mordred**, and 3D descriptors like **ACSF**, **MBTR**, **SOAP** and **LMBTR**. In addition, the paramters of these modules can be modified.

# %%
gen2d = generate2Ddesc(df)
rdkit_desc_map = gen2d.calc_rdkit_desc()
radius = 4
nBits = 2048
mf_desc_map = gen2d.calc_mf_desc(radius,nBits=nBits,useChirality=True)
# Out:
# Traceback (most recent call last):
#   File "D:\DevTools\anaconda3\envs\aho_py310\lib\site-packages\rdkit\ML\Descriptors\MoleculeDescriptors.py", line 86, in CalcDescriptors
#     res[i] = fn(mol)
#   File "D:\DevTools\anaconda3\envs\aho_py310\lib\site-packages\rdkit\Chem\EState\EState.py", line 89, in MaxAbsEStateIndex
#     return max(abs(x) for x in EStateIndices(mol, force))
#   File "D:\DevTools\anaconda3\envs\aho_py310\lib\site-packages\rdkit\Chem\EState\EState.py", line 45, in EStateIndices
#     nAtoms = mol.GetNumAtoms()
# AttributeError: 'NoneType' object has no attribute 'GetNumAtoms'
# Traceback (most recent call last):
#   File "D:\DevTools\anaconda3\envs\aho_py310\lib\site-packages\rdkit\ML\Descriptors\MoleculeDescriptors.py", line 86, in CalcDescriptors
#     res[i] = fn(mol)
#   File "D:\DevTools\anaconda3\envs\aho_py310\lib\site-packages\rdkit\Chem\EState\EState.py", line 75, in MaxEStateIndex
#     return max(EStateIndices(mol, force))
#   File "D:\DevTools\anaconda3\envs\aho_py310\lib\site-packages\rdkit\Chem\EState\EState.py", line 45, in EStateIndices
#     nAtoms = mol.GetNumAtoms()
# AttributeError: 'NoneType' object has no attribute 'GetNumAtoms'
# Traceback (most recent call last):
#   File "D:\DevTools\anaconda3\envs\aho_py310\lib\site-packages\rdkit\ML\Descriptors\MoleculeDescriptors.py", line 86, in CalcDescriptors
#     res[i] = fn(mol)
#   File "D:\DevTools\anaconda3\envs\aho_py310\lib\site-packages\rdkit\Chem\EState\EState.py", line 96, in MinAbsEStateIndex
#     return min(abs(x) for x in EStateIndices(mol, force))
#   File "D:\DevTools\anaconda3\envs\aho_py310\lib\site-packages\rdkit\Chem\EState\EState.py", line 45, in EStateIndices
#     nAtoms = mol.GetNumAtoms()
# AttributeError: 'NoneType' object has no attribute 'GetNumAtoms'
# Traceback (most recent call last):
#   File "D:\DevTools\anaconda3\envs\aho_py310\lib\site-packages\rdkit\ML\Descriptors\MoleculeDescriptors.py", line 86, in CalcDescriptors
#     res[i] = fn(mol)
#   File "D:\DevTools\anaconda3\envs\aho_py310\lib\site-packages\rdkit\Chem\EState\EState.py", line 82, in MinEStateIndex
#     return min(EStateIndices(mol, force))
#   File "D:\DevTools\anaconda3\envs\aho_py310\lib\site-packages\rdkit\Chem\EState\EState.py", line 45, in EStateIndices
#     nAtoms = mol.GetNumAtoms()
# AttributeError: 'NoneType' object has no attribute 'GetNumAtoms'
# Traceback (most recent call last):
#   File "D:\DevTools\anaconda3\envs\aho_py310\lib\site-packages\rdkit\ML\Descriptors\MoleculeDescriptors.py", line 86, in CalcDescriptors
#     res[i] = fn(mol)
#   File "D:\DevTools\anaconda3\envs\aho_py310\lib\site-packages\rdkit\Chem\QED.py", line 203, in qed
#     qedProperties = properties(mol)
#   File "D:\DevTools\anaconda3\envs\aho_py310\lib\site-packages\rdkit\Chem\QED.py", line 164, in properties
#     raise ValueError('You need to provide a mol argument.')
# ValueError: You need to provide a mol argument.
# Traceback (most recent call last):
#   File "D:\DevTools\anaconda3\envs\aho_py310\lib\site-packages\rdkit\ML\Descriptors\MoleculeDescriptors.py", line 86, in CalcDescriptors
#     res[i] = fn(mol)
#   File "D:\DevTools\anaconda3\envs\aho_py310\lib\site-packages\rdkit\Chem\SpacialScore.py", line 72, in SPS
#     return _SpacialScore(mol, normalize=normalize).score
#   File "D:\DevTools\anaconda3\envs\aho_py310\lib\site-packages\rdkit\Chem\SpacialScore.py", line 80, in __init__
#     raise ValueError("No valid molecule object found.")
# ValueError: No valid molecule object found.
# Traceback (most recent call last):
#   File "D:\DevTools\anaconda3\envs\aho_py310\lib\site-packages\rdkit\ML\Descriptors\MoleculeDescriptors.py", line 86, in CalcDescriptors
#     res[i] = fn(mol)
#   File "D:\DevTools\anaconda3\envs\aho_py310\lib\site-packages\rdkit\Chem\Descriptors.py", line 75, in <lambda>
#     MolWt = lambda *x, **y: _rdMolDescriptors._CalcMolWt(*x, **y)
# Boost.Python.ArgumentError: Python argument types in
#     None._CalcMolWt(NoneType)
# did not match C++ signature:
#     _CalcMolWt(class RDKit::ROMol mol, bool onlyHeavy=False)
# Traceback (most recent call last):
#   File "D:\DevTools\anaconda3\envs\aho_py310\lib\site-packages\rdkit\ML\Descriptors\MoleculeDescriptors.py", line 86, in CalcDescriptors
#     res[i] = fn(mol)
#   File "D:\DevTools\anaconda3\envs\aho_py310\lib\site-packages\rdkit\Chem\Descriptors.py", line 88, in HeavyAtomMolWt
#     return MolWt(x, True)
#   File "D:\DevTools\anaconda3\envs\aho_py310\lib\site-packages\rdkit\Chem\Descriptors.py", line 75, in <lambda>
#     MolWt = lambda *x, **y: _rdMolDescriptors._CalcMolWt(*x, **y)
# Boost.Python.ArgumentError: Python argument types in
#     None._CalcMolWt(NoneType, bool)
# did not match C++ signature:
#     _CalcMolWt(class RDKit::ROMol mol, bool onlyHeavy=False)
# Traceback (most recent call last):
#   File "D:\DevTools\anaconda3\envs\aho_py310\lib\site-packages\rdkit\ML\Descriptors\MoleculeDescriptors.py", line 86, in CalcDescriptors
#     res[i] = fn(mol)
#   File "D:\DevTools\anaconda3\envs\aho_py310\lib\site-packages\rdkit\Chem\Descriptors.py", line 101, in <lambda>
#     ExactMolWt = lambda *x, **y: _rdMolDescriptors.CalcExactMolWt(*x, **y)
# Boost.Python.ArgumentError: Python argument types in
#     None.CalcExactMolWt(NoneType)
# did not match C++ signature:
#     CalcExactMolWt(class RDKit::ROMol mol, bool onlyHeavy=False)
# Traceback (most recent call last):
#   File "D:\DevTools\anaconda3\envs\aho_py310\lib\site-packages\rdkit\ML\Descriptors\MoleculeDescriptors.py", line 86, in CalcDescriptors
#     res[i] = fn(mol)
#   File "D:\DevTools\anaconda3\envs\aho_py310\lib\site-packages\rdkit\Chem\Descriptors.py", line 129, in NumValenceElectrons
#     for atom in mol.GetAtoms())
# AttributeError: 'NoneType' object has no attribute 'GetAtoms'
# Traceback (most recent call last):
#   File "D:\DevTools\anaconda3\envs\aho_py310\lib\site-packages\rdkit\ML\Descriptors\MoleculeDescriptors.py", line 86, in CalcDescriptors
#     res[i] = fn(mol)
#   File "D:\DevTools\anaconda3\envs\aho_py310\lib\site-packages\rdkit\Chem\Descriptors.py", line 151, in NumRadicalElectrons
#     return sum(atom.GetNumRadicalElectrons() for atom in mol.GetAtoms())
# AttributeError: 'NoneType' object has no attribute 'GetAtoms'
# Traceback (most recent call last):
#   File "D:\DevTools\anaconda3\envs\aho_py310\lib\site-packages\rdkit\ML\Descriptors\MoleculeDescriptors.py", line 86, in CalcDescriptors
#     res[i] = fn(mol)
#   File "D:\DevTools\anaconda3\envs\aho_py310\lib\site-packages\rdkit\Chem\Descriptors.py", line 173, in MaxPartialCharge
#     _, res = _ChargeDescriptors(mol, force)
#   File "D:\DevTools\anaconda3\envs\aho_py310\lib\site-packages\rdkit\Chem\Descriptors.py", line 160, in _ChargeDescriptors
#     chgs = rdPartialCharges.ComputeGasteigerCharges(mol)
# Boost.Python.ArgumentError: Python argument types in
#     None.ComputeGasteigerCharges(NoneType)
# did not match C++ signature:
#     ComputeGasteigerCharges(class RDKit::ROMol mol, int nIter=12, bool throwOnParamFailure=False)
# Traceback (most recent call last):
#   File "D:\DevTools\anaconda3\envs\aho_py310\lib\site-packages\rdkit\ML\Descriptors\MoleculeDescriptors.py", line 86, in CalcDescriptors
#     res[i] = fn(mol)
#   File "D:\DevTools\anaconda3\envs\aho_py310\lib\site-packages\rdkit\Chem\Descriptors.py", line 181, in MinPartialCharge
#     res, _ = _ChargeDescriptors(mol, force)
#   File "D:\DevTools\anaconda3\envs\aho_py310\lib\site-packages\rdkit\Chem\Descriptors.py", line 160, in _ChargeDescriptors
#     chgs = rdPartialCharges.ComputeGasteigerCharges(mol)
# Boost.Python.ArgumentError: Python argument types in
#     None.ComputeGasteigerCharges(NoneType)
# did not match C++ signature:
#     ComputeGasteigerCharges(class RDKit::ROMol mol, int nIter=12, bool throwOnParamFailure=False)
# Traceback (most recent call last):
#   File "D:\DevTools\anaconda3\envs\aho_py310\lib\site-packages\rdkit\ML\Descriptors\MoleculeDescriptors.py", line 86, in CalcDescriptors
#     res[i] = fn(mol)
#   File "D:\DevTools\anaconda3\envs\aho_py310\lib\site-packages\rdkit\Chem\Descriptors.py", line 189, in MaxAbsPartialCharge
#     v1, v2 = _ChargeDescriptors(mol, force)
#   File "D:\DevTools\anaconda3\envs\aho_py310\lib\site-packages\rdkit\Chem\Descriptors.py", line 160, in _ChargeDescriptors
#     chgs = rdPartialCharges.ComputeGasteigerCharges(mol)
# Boost.Python.ArgumentError: Python argument types in
#     None.ComputeGasteigerCharges(NoneType)
# did not match C++ signature:
#     ComputeGasteigerCharges(class RDKit::ROMol mol, int nIter=12, bool throwOnParamFailure=False)
# Traceback (most recent call last):
#   File "D:\DevTools\anaconda3\envs\aho_py310\lib\site-packages\rdkit\ML\Descriptors\MoleculeDescriptors.py", line 86, in CalcDescriptors
#     res[i] = fn(mol)
#   File "D:\DevTools\anaconda3\envs\aho_py310\lib\site-packages\rdkit\Chem\Descriptors.py", line 197, in MinAbsPartialCharge
#     v1, v2 = _ChargeDescriptors(mol, force)
#   File "D:\DevTools\anaconda3\envs\aho_py310\lib\site-packages\rdkit\Chem\Descriptors.py", line 160, in _ChargeDescriptors
#     chgs = rdPartialCharges.ComputeGasteigerCharges(mol)
# Boost.Python.ArgumentError: Python argument types in
#     None.ComputeGasteigerCharges(NoneType)
# did not match C++ signature:
#     ComputeGasteigerCharges(class RDKit::ROMol mol, int nIter=12, bool throwOnParamFailure=False)
# Traceback (most recent call last):
#   File "D:\DevTools\anaconda3\envs\aho_py310\lib\site-packages\rdkit\ML\Descriptors\MoleculeDescriptors.py", line 86, in CalcDescriptors
#     res[i] = fn(mol)
#   File "D:\DevTools\anaconda3\envs\aho_py310\lib\site-packages\rdkit\Chem\Descriptors.py", line 229, in FpDensityMorgan1
#     return _FingerprintDensity(x, _getMorganCountFingerprint, 1)
#   File "D:\DevTools\anaconda3\envs\aho_py310\lib\site-packages\rdkit\Chem\Descriptors.py", line 209, in _FingerprintDensity
#     fp = func(*((mol, ) + args), **kwargs)
#   File "D:\DevTools\anaconda3\envs\aho_py310\lib\site-packages\rdkit\Chem\Descriptors.py", line 225, in _getMorganCountFingerprint
#     return fpg.GetSparseCountFingerprint(mol)
# Boost.Python.ArgumentError: Python argument types in
#     FingerprintGenerator64.GetSparseCountFingerprint(FingerprintGenerator64, NoneType)
# did not match C++ signature:
#     GetSparseCountFingerprint(class RDKit::FingerprintGenerator<unsigned __int64> const * __ptr64 self, class RDKit::ROMol mol, class boost::python::api::object fromAtoms=[], class boost::python::api::object ignoreAtoms=[], int confId=-1, class boost::python::api::object customAtomInvariants=[], class boost::python::api::object customBondInvariants=[], class boost::python::api::object additionalOutput=None)
# Traceback (most recent call last):
#   File "D:\DevTools\anaconda3\envs\aho_py310\lib\site-packages\rdkit\ML\Descriptors\MoleculeDescriptors.py", line 86, in CalcDescriptors
#     res[i] = fn(mol)
#   File "D:\DevTools\anaconda3\envs\aho_py310\lib\site-packages\rdkit\Chem\Descriptors.py", line 233, in FpDensityMorgan2
#     return _FingerprintDensity(x, _getMorganCountFingerprint, 2)
#   File "D:\DevTools\anaconda3\envs\aho_py310\lib\site-packages\rdkit\Chem\Descriptors.py", line 209, in _FingerprintDensity
#     fp = func(*((mol, ) + args), **kwargs)
#   File "D:\DevTools\anaconda3\envs\aho_py310\lib\site-packages\rdkit\Chem\Descriptors.py", line 225, in _getMorganCountFingerprint
#     return fpg.GetSparseCountFingerprint(mol)
# Boost.Python.ArgumentError: Python argument types in
#     FingerprintGenerator64.GetSparseCountFingerprint(FingerprintGenerator64, NoneType)
# did not match C++ signature:
#     GetSparseCountFingerprint(class RDKit::FingerprintGenerator<unsigned __int64> const * __ptr64 self, class RDKit::ROMol mol, class boost::python::api::object fromAtoms=[], class boost::python::api::object ignoreAtoms=[], int confId=-1, class boost::python::api::object customAtomInvariants=[], class boost::python::api::object customBondInvariants=[], class boost::python::api::object additionalOutput=None)
# Traceback (most recent call last):
#   File "D:\DevTools\anaconda3\envs\aho_py310\lib\site-packages\rdkit\ML\Descriptors\MoleculeDescriptors.py", line 86, in CalcDescriptors
#     res[i] = fn(mol)
#   File "D:\DevTools\anaconda3\envs\aho_py310\lib\site-packages\rdkit\Chem\Descriptors.py", line 237, in FpDensityMorgan3
#     return _FingerprintDensity(x, _getMorganCountFingerprint, 3)
#   File "D:\DevTools\anaconda3\envs\aho_py310\lib\site-packages\rdkit\Chem\Descriptors.py", line 209, in _FingerprintDensity
#     fp = func(*((mol, ) + args), **kwargs)
#   File "D:\DevTools\anaconda3\envs\aho_py310\lib\site-packages\rdkit\Chem\Descriptors.py", line 225, in _getMorganCountFingerprint
#     return fpg.GetSparseCountFingerprint(mol)
# Boost.Python.ArgumentError: Python argument types in
#     FingerprintGenerator64.GetSparseCountFingerprint(FingerprintGenerator64, NoneType)
# did not match C++ signature:
#     GetSparseCountFingerprint(class RDKit::FingerprintGenerator<unsigned __int64> const * __ptr64 self, class RDKit::ROMol mol, class boost::python::api::object fromAtoms=[], class boost::python::api::object ignoreAtoms=[], int confId=-1, class boost::python::api::object customAtomInvariants=[], class boost::python::api::object customBondInvariants=[], class boost::python::api::object additionalOutput=None)
# Traceback (most recent call last):
#   File "D:\DevTools\anaconda3\envs\aho_py310\lib\site-packages\rdkit\Chem\GraphDescriptors.py", line 122, in Ipc
#     dMat = mol._adjMat
# AttributeError: 'NoneType' object has no attribute '_adjMat'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "D:\DevTools\anaconda3\envs\aho_py310\lib\site-packages\rdkit\ML\Descriptors\MoleculeDescriptors.py", line 86, in CalcDescriptors
#     res[i] = fn(mol)
#   File "D:\DevTools\anaconda3\envs\aho_py310\lib\site-packages\rdkit\Chem\GraphDescriptors.py", line 145, in AvgIpc
#     return Ipc(mol, avg=True, dMat=dMat, forceDMat=forceDMat)
#   File "D:\DevTools\anaconda3\envs\aho_py310\lib\site-packages\rdkit\Chem\GraphDescriptors.py", line 124, in Ipc
#     dMat = Chem.GetDistanceMatrix(mol, 0)
# Boost.Python.ArgumentError: Python argument types in
#     None.GetDistanceMatrix(NoneType, int)
# did not match C++ signature:
#     GetDistanceMatrix(class RDKit::ROMol {lvalue} mol, bool useBO=False, bool useAtomWts=False, bool force=False, char const * __ptr64 prefix='')
# Traceback (most recent call last):
#   File "D:\DevTools\anaconda3\envs\aho_py310\lib\site-packages\rdkit\Chem\GraphDescriptors.py", line 486, in BalabanJ
#     dMat = mol._balabanMat
# AttributeError: 'NoneType' object has no attribute '_balabanMat'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "D:\DevTools\anaconda3\envs\aho_py310\lib\site-packages\rdkit\ML\Descriptors\MoleculeDescriptors.py", line 86, in CalcDescriptors
#     res[i] = fn(mol)
#   File "D:\DevTools\anaconda3\envs\aho_py310\lib\site-packages\rdkit\Chem\GraphDescriptors.py", line 489, in BalabanJ
#     dMat = Chem.GetDistanceMatrix(mol, useBO=1, useAtomWts=0, force=0, prefix="Balaban")
# Boost.Python.ArgumentError: Python argument types in
#     None.GetDistanceMatrix(NoneType)
# did not match C++ signature:
#     GetDistanceMatrix(class RDKit::ROMol {lvalue} mol, bool useBO=False, bool useAtomWts=False, bool force=False, char const * __ptr64 prefix='')
# Traceback (most recent call last):
#   File "D:\DevTools\anaconda3\envs\aho_py310\lib\site-packages\rdkit\ML\Descriptors\MoleculeDescriptors.py", line 86, in CalcDescriptors
#     res[i] = fn(mol)
#   File "D:\DevTools\anaconda3\envs\aho_py310\lib\site-packages\rdkit\Chem\GraphDescriptors.py", line 664, in BertzCT
#     numAtoms = mol.GetNumAtoms()
# AttributeError: 'NoneType' object has no attribute 'GetNumAtoms'
# Traceback (most recent call last):
#   File "D:\DevTools\anaconda3\envs\aho_py310\lib\site-packages\rdkit\ML\Descriptors\MoleculeDescriptors.py", line 86, in CalcDescriptors
#     res[i] = fn(mol)
#   File "D:\DevTools\anaconda3\envs\aho_py310\lib\site-packages\rdkit\Chem\GraphDescriptors.py", line 227, in Chi0
#     deltas = [x.GetDegree() for x in mol.GetAtoms()]
# AttributeError: 'NoneType' object has no attribute 'GetAtoms'
# Traceback (most recent call last):
#   File "D:\DevTools\anaconda3\envs\aho_py310\lib\site-packages\rdkit\ML\Descriptors\MoleculeDescriptors.py", line 86, in CalcDescriptors
#     res[i] = fn(mol)
#   File "D:\DevTools\anaconda3\envs\aho_py310\lib\site-packages\rdkit\Chem\GraphDescriptors.py", line 439, in <lambda>
#     Chi0n = lambda x: rdMolDescriptors.CalcChi0n(x)
# Boost.Python.ArgumentError: Python argument types in
#     None.CalcChi0n(NoneType)
# did not match C++ signature:
#     CalcChi0n(class RDKit::ROMol mol, bool force=False)
# Traceback (most recent call last):
#   File "D:\DevTools\anaconda3\envs\aho_py310\lib\site-packages\rdkit\ML\Descriptors\MoleculeDescriptors.py", line 86, in CalcDescriptors
#     res[i] = fn(mol)
#   File "D:\DevTools\anaconda3\envs\aho_py310\lib\site-packages\rdkit\Chem\GraphDescriptors.py", line 426, in <lambda>
#     Chi0v = lambda x: rdMolDescriptors.CalcChi0v(x)
# Boost.Python.ArgumentError: Python argument types in
#     None.CalcChi0v(NoneType)
# did not match C++ signature:
#     CalcChi0v(class RDKit::ROMol mol, bool force=False)
# Traceback (most recent call last):
#   File "D:\DevTools\anaconda3\envs\aho_py310\lib\site-packages\rdkit\ML\Descriptors\MoleculeDescriptors.py", line 86, in CalcDescriptors
#     res[i] = fn(mol)
#   File "D:\DevTools\anaconda3\envs\aho_py310\lib\site-packages\rdkit\Chem\GraphDescriptors.py", line 242, in Chi1
#     c1s = [x.GetBeginAtom().GetDegree() * x.GetEndAtom().GetDegree() for x in mol.GetBonds()]
# AttributeError: 'NoneType' object has no attribute 'GetBonds'
# Traceback (most recent call last):
#   File "D:\DevTools\anaconda3\envs\aho_py310\lib\site-packages\rdkit\ML\Descriptors\MoleculeDescriptors.py", line 86, in CalcDescriptors
#     res[i] = fn(mol)
#   File "D:\DevTools\anaconda3\envs\aho_py310\lib\site-packages\rdkit\Chem\GraphDescriptors.py", line 441, in <lambda>
#     Chi1n = lambda x: rdMolDescriptors.CalcChi1n(x)
# Boost.Python.ArgumentError: Python argument types in
#     None.CalcChi1n(NoneType)
# did not match C++ signature:
#     CalcChi1n(class RDKit::ROMol mol, bool force=False)
# Traceback (most recent call last):
#   File "D:\DevTools\anaconda3\envs\aho_py310\lib\site-packages\rdkit\ML\Descriptors\MoleculeDescriptors.py", line 86, in CalcDescriptors
#     res[i] = fn(mol)
#   File "D:\DevTools\anaconda3\envs\aho_py310\lib\site-packages\rdkit\Chem\GraphDescriptors.py", line 428, in <lambda>
#     Chi1v = lambda x: rdMolDescriptors.CalcChi1v(x)
# Boost.Python.ArgumentError: Python argument types in
#     None.CalcChi1v(NoneType)
# did not match C++ signature:
#     CalcChi1v(class RDKit::ROMol mol, bool force=False)
# Traceback (most recent call last):
#   File "D:\DevTools\anaconda3\envs\aho_py310\lib\site-packages\rdkit\ML\Descriptors\MoleculeDescriptors.py", line 86, in CalcDescriptors
#     res[i] = fn(mol)
#   File "D:\DevTools\anaconda3\envs\aho_py310\lib\site-packages\rdkit\Chem\GraphDescriptors.py", line 443, in <lambda>
#     Chi2n = lambda x: rdMolDescriptors.CalcChi2n(x)
# Boost.Python.ArgumentError: Python argument types in
#     None.CalcChi2n(NoneType)
# did not match C++ signature:
#     CalcChi2n(class RDKit::ROMol mol, bool force=False)
# Traceback (most recent call last):
#   File "D:\DevTools\anaconda3\envs\aho_py310\lib\site-packages\rdkit\ML\Descriptors\MoleculeDescriptors.py", line 86, in CalcDescriptors
#     res[i] = fn(mol)
#   File "D:\DevTools\anaconda3\envs\aho_py310\lib\site-packages\rdkit\Chem\GraphDescriptors.py", line 430, in <lambda>
#     Chi2v = lambda x: rdMolDescriptors.CalcChi2v(x)
# Boost.Python.ArgumentError: Python argument types in
#     None.CalcChi2v(NoneType)
# did not match C++ signature:
#     CalcChi2v(class RDKit::ROMol mol, bool force=False)
# Traceback (most recent call last):
#   File "D:\DevTools\anaconda3\envs\aho_py310\lib\site-packages\rdkit\ML\Descriptors\MoleculeDescriptors.py", line 86, in CalcDescriptors
#     res[i] = fn(mol)
#   File "D:\DevTools\anaconda3\envs\aho_py310\lib\site-packages\rdkit\Chem\GraphDescriptors.py", line 445, in <lambda>
#     Chi3n = lambda x: rdMolDescriptors.CalcChi3n(x)
# Boost.Python.ArgumentError: Python argument types in
#     None.CalcChi3n(NoneType)
# did not match C++ signature:
#     CalcChi3n(class RDKit::ROMol mol, bool force=False)
# Traceback (most recent call last):
#   File "D:\DevTools\anaconda3\envs\aho_py310\lib\site-packages\rdkit\ML\Descriptors\MoleculeDescriptors.py", line 86, in CalcDescriptors
#     res[i] = fn(mol)
#   File "D:\DevTools\anaconda3\envs\aho_py310\lib\site-packages\rdkit\Chem\GraphDescriptors.py", line 432, in <lambda>
#     Chi3v = lambda x: rdMolDescriptors.CalcChi3v(x)
# Boost.Python.ArgumentError: Python argument types in
#     None.CalcChi3v(NoneType)
# did not match C++ signature:
#     CalcChi3v(class RDKit::ROMol mol, bool force=False)
# Traceback (most recent call last):
#   File "D:\DevTools\anaconda3\envs\aho_py310\lib\site-packages\rdkit\ML\Descriptors\MoleculeDescriptors.py", line 86, in CalcDescriptors
#     res[i] = fn(mol)
#   File "D:\DevTools\anaconda3\envs\aho_py310\lib\site-packages\rdkit\Chem\GraphDescriptors.py", line 447, in <lambda>
#     Chi4n = lambda x: rdMolDescriptors.CalcChi4n(x)
# Boost.Python.ArgumentError: Python argument types in
#     None.CalcChi4n(NoneType)
# did not match C++ signature:
#     CalcChi4n(class RDKit::ROMol mol, bool force=False)
# Traceback (most recent call last):
#   File "D:\DevTools\anaconda3\envs\aho_py310\lib\site-packages\rdkit\ML\Descriptors\MoleculeDescriptors.py", line 86, in CalcDescriptors
#     res[i] = fn(mol)
#   File "D:\DevTools\anaconda3\envs\aho_py310\lib\site-packages\rdkit\Chem\GraphDescriptors.py", line 434, in <lambda>
#     Chi4v = lambda x: rdMolDescriptors.CalcChi4v(x)
# Boost.Python.ArgumentError: Python argument types in
#     None.CalcChi4v(NoneType)
# did not match C++ signature:
#     CalcChi4v(class RDKit::ROMol mol, bool force=False)
# Traceback (most recent call last):
#   File "D:\DevTools\anaconda3\envs\aho_py310\lib\site-packages\rdkit\ML\Descriptors\MoleculeDescriptors.py", line 86, in CalcDescriptors
#     res[i] = fn(mol)
#   File "D:\DevTools\anaconda3\envs\aho_py310\lib\site-packages\rdkit\Chem\GraphDescriptors.py", line 213, in <lambda>
#     HallKierAlpha = lambda x: rdMolDescriptors.CalcHallKierAlpha(x)
# Boost.Python.ArgumentError: Python argument types in
#     None.CalcHallKierAlpha(NoneType)
# did not match C++ signature:
#     CalcHallKierAlpha(class RDKit::ROMol mol, class boost::python::api::object atomContribs=None)
# Traceback (most recent call last):
#   File "D:\DevTools\anaconda3\envs\aho_py310\lib\site-packages\rdkit\Chem\GraphDescriptors.py", line 122, in Ipc
#     dMat = mol._adjMat
# AttributeError: 'NoneType' object has no attribute '_adjMat'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "D:\DevTools\anaconda3\envs\aho_py310\lib\site-packages\rdkit\ML\Descriptors\MoleculeDescriptors.py", line 86, in CalcDescriptors
#     res[i] = fn(mol)
#   File "D:\DevTools\anaconda3\envs\aho_py310\lib\site-packages\rdkit\Chem\GraphDescriptors.py", line 124, in Ipc
#     dMat = Chem.GetDistanceMatrix(mol, 0)
# Boost.Python.ArgumentError: Python argument types in
#     None.GetDistanceMatrix(NoneType, int)
# did not match C++ signature:
#     GetDistanceMatrix(class RDKit::ROMol {lvalue} mol, bool useBO=False, bool useAtomWts=False, bool force=False, char const * __ptr64 prefix='')
# Traceback (most recent call last):
#   File "D:\DevTools\anaconda3\envs\aho_py310\lib\site-packages\rdkit\ML\Descriptors\MoleculeDescriptors.py", line 86, in CalcDescriptors
#     res[i] = fn(mol)
#   File "D:\DevTools\anaconda3\envs\aho_py310\lib\site-packages\rdkit\Chem\GraphDescriptors.py", line 215, in <lambda>
#     Kappa1 = lambda x: rdMolDescriptors.CalcKappa1(x)
# Boost.Python.ArgumentError: Python argument types in
#     None.CalcKappa1(NoneType)
# did not match C++ signature:
#     CalcKappa1(class RDKit::ROMol mol)
# Traceback (most recent call last):
#   File "D:\DevTools\anaconda3\envs\aho_py310\lib\site-packages\rdkit\ML\Descriptors\MoleculeDescriptors.py", line 86, in CalcDescriptors
#     res[i] = fn(mol)
#   File "D:\DevTools\anaconda3\envs\aho_py310\lib\site-packages\rdkit\Chem\GraphDescriptors.py", line 217, in <lambda>
#     Kappa2 = lambda x: rdMolDescriptors.CalcKappa2(x)
# Boost.Python.ArgumentError: Python argument types in
#     None.CalcKappa2(NoneType)
# did not match C++ signature:
#     CalcKappa2(class RDKit::ROMol mol)
# Traceback (most recent call last):
#   File "D:\DevTools\anaconda3\envs\aho_py310\lib\site-packages\rdkit\ML\Descriptors\MoleculeDescriptors.py", line 86, in CalcDescriptors
#     res[i] = fn(mol)
#   File "D:\DevTools\anaconda3\envs\aho_py310\lib\site-packages\rdkit\Chem\GraphDescriptors.py", line 219, in <lambda>
#     Kappa3 = lambda x: rdMolDescriptors.CalcKappa3(x)
# Boost.Python.ArgumentError: Python argument types in
#     None.CalcKappa3(NoneType)
# did not match C++ signature:
#     CalcKappa3(class RDKit::ROMol mol)
# Traceback (most recent call last):
#   File "D:\DevTools\anaconda3\envs\aho_py310\lib\site-packages\rdkit\ML\Descriptors\MoleculeDescriptors.py", line 86, in CalcDescriptors
#     res[i] = fn(mol)
#   File "D:\DevTools\anaconda3\envs\aho_py310\lib\site-packages\rdkit\Chem\MolSurf.py", line 311, in <lambda>
#     LabuteASA = lambda *x, **y: rdMolDescriptors.CalcLabuteASA(*x, **y)
# Boost.Python.ArgumentError: Python argument types in
#     None.CalcLabuteASA(NoneType)
# did not match C++ signature:
#     CalcLabuteASA(class RDKit::ROMol mol, bool includeHs=True, bool force=False)
# Traceback (most recent call last):
#   File "D:\DevTools\anaconda3\envs\aho_py310\lib\site-packages\rdkit\ML\Descriptors\MoleculeDescriptors.py", line 86, in CalcDescriptors
#     res[i] = fn(mol)
#   File "D:\DevTools\anaconda3\envs\aho_py310\lib\site-packages\rdkit\Chem\MolSurf.py", line 274, in <lambda>
#     fn = lambda x, y=i: PEOE_VSA_(x, force=0)[y]
# Boost.Python.ArgumentError: Python argument types in
#     None.PEOE_VSA_(NoneType)
# did not match C++ signature:
#     PEOE_VSA_(class RDKit::ROMol mol, class boost::python::api::object bins=[], bool force=False)
# Traceback (most recent call last):
#   File "D:\DevTools\anaconda3\envs\aho_py310\lib\site-packages\rdkit\ML\Descriptors\MoleculeDescriptors.py", line 86, in CalcDescriptors
#     res[i] = fn(mol)
#   File "D:\DevTools\anaconda3\envs\aho_py310\lib\site-packages\rdkit\Chem\MolSurf.py", line 274, in <lambda>
#     fn = lambda x, y=i: PEOE_VSA_(x, force=0)[y]
# Boost.Python.ArgumentError: Python argument types in
#     None.PEOE_VSA_(NoneType)
# did not match C++ signature:
#     PEOE_VSA_(class RDKit::ROMol mol, class boost::python::api::object bins=[], bool force=False)
# Traceback (most recent call last):
#   File "D:\DevTools\anaconda3\envs\aho_py310\lib\site-packages\rdkit\ML\Descriptors\MoleculeDescriptors.py", line 86, in CalcDescriptors
#     res[i] = fn(mol)
#   File "D:\DevTools\anaconda3\envs\aho_py310\lib\site-packages\rdkit\Chem\MolSurf.py", line 274, in <lambda>
#     fn = lambda x, y=i: PEOE_VSA_(x, force=0)[y]
# Boost.Python.ArgumentError: Python argument types in
#     None.PEOE_VSA_(NoneType)
# did not match C++ signature:
#     PEOE_VSA_(class RDKit::ROMol mol, class boost::python::api::object bins=[], bool force=False)
# Traceback (most recent call last):
#   File "D:\DevTools\anaconda3\envs\aho_py310\lib\site-packages\rdkit\ML\Descriptors\MoleculeDescriptors.py", line 86, in CalcDescriptors
#     res[i] = fn(mol)
#   File "D:\DevTools\anaconda3\envs\aho_py310\lib\site-packages\rdkit\Chem\MolSurf.py", line 274, in <lambda>
#     fn = lambda x, y=i: PEOE_VSA_(x, force=0)[y]
# Boost.Python.ArgumentError: Python argument types in
#     None.PEOE_VSA_(NoneType)
# did not match C++ signature:
#     PEOE_VSA_(class RDKit::ROMol mol, class boost::python::api::object bins=[], bool force=False)
# Traceback (most recent call last):
#   File "D:\DevTools\anaconda3\envs\aho_py310\lib\site-packages\rdkit\ML\Descriptors\MoleculeDescriptors.py", line 86, in CalcDescriptors
#     res[i] = fn(mol)
#   File "D:\DevTools\anaconda3\envs\aho_py310\lib\site-packages\rdkit\Chem\MolSurf.py", line 274, in <lambda>
#     fn = lambda x, y=i: PEOE_VSA_(x, force=0)[y]
# Boost.Python.ArgumentError: Python argument types in
#     None.PEOE_VSA_(NoneType)
# did not match C++ signature:
#     PEOE_VSA_(class RDKit::ROMol mol, class boost::python::api::object bins=[], bool force=False)
# Traceback (most recent call last):
#   File "D:\DevTools\anaconda3\envs\aho_py310\lib\site-packages\rdkit\ML\Descriptors\MoleculeDescriptors.py", line 86, in CalcDescriptors
#     res[i] = fn(mol)
#   File "D:\DevTools\anaconda3\envs\aho_py310\lib\site-packages\rdkit\Chem\MolSurf.py", line 284, in <lambda>
#     fn = lambda x, y=i: PEOE_VSA_(x, force=0)[y]
# Boost.Python.ArgumentError: Python argument types in
#     None.PEOE_VSA_(NoneType)
# did not match C++ signature:
#     PEOE_VSA_(class RDKit::ROMol mol, class boost::python::api::object bins=[], bool force=False)
# Traceback (most recent call last):
#   File "D:\DevTools\anaconda3\envs\aho_py310\lib\site-packages\rdkit\ML\Descriptors\MoleculeDescriptors.py", line 86, in CalcDescriptors
#     res[i] = fn(mol)
#   File "D:\DevTools\anaconda3\envs\aho_py310\lib\site-packages\rdkit\Chem\MolSurf.py", line 274, in <lambda>
#     fn = lambda x, y=i: PEOE_VSA_(x, force=0)[y]
# Boost.Python.ArgumentError: Python argument types in
#     None.PEOE_VSA_(NoneType)
# did not match C++ signature:
#     PEOE_VSA_(class RDKit::ROMol mol, class boost::python::api::object bins=[], bool force=False)
# Traceback (most recent call last):
#   File "D:\DevTools\anaconda3\envs\aho_py310\lib\site-packages\rdkit\ML\Descriptors\MoleculeDescriptors.py", line 86, in CalcDescriptors
#     res[i] = fn(mol)
#   File "D:\DevTools\anaconda3\envs\aho_py310\lib\site-packages\rdkit\Chem\MolSurf.py", line 274, in <lambda>
#     fn = lambda x, y=i: PEOE_VSA_(x, force=0)[y]
# Boost.Python.ArgumentError: Python argument types in
#     None.PEOE_VSA_(NoneType)
# did not match C++ signature:
#     PEOE_VSA_(class RDKit::ROMol mol, class boost::python::api::object bins=[], bool force=False)
# Traceback (most recent call last):
#   File "D:\DevTools\anaconda3\envs\aho_py310\lib\site-packages\rdkit\ML\Descriptors\MoleculeDescriptors.py", line 86, in CalcDescriptors
#     res[i] = fn(mol)
#   File "D:\DevTools\anaconda3\envs\aho_py310\lib\site-packages\rdkit\Chem\MolSurf.py", line 274, in <lambda>
#     fn = lambda x, y=i: PEOE_VSA_(x, force=0)[y]
# Boost.Python.ArgumentError: Python argument types in
#     None.PEOE_VSA_(NoneType)
# did not match C++ signature:
#     PEOE_VSA_(class RDKit::ROMol mol, class boost::python::api::object bins=[], bool force=False)
# Traceback (most recent call last):
#   File "D:\DevTools\anaconda3\envs\aho_py310\lib\site-packages\rdkit\ML\Descriptors\MoleculeDescriptors.py", line 86, in CalcDescriptors
#     res[i] = fn(mol)
#   File "D:\DevTools\anaconda3\envs\aho_py310\lib\site-packages\rdkit\Chem\MolSurf.py", line 274, in <lambda>
#     fn = lambda x, y=i: PEOE_VSA_(x, force=0)[y]
# Boost.Python.ArgumentError: Python argument types in
#     None.PEOE_VSA_(NoneType)
# did not match C++ signature:
#     PEOE_VSA_(class RDKit::ROMol mol, class boost::python::api::object bins=[], bool force=False)
# Traceback (most recent call last):
#   File "D:\DevTools\anaconda3\envs\aho_py310\lib\site-packages\rdkit\ML\Descriptors\MoleculeDescriptors.py", line 86, in CalcDescriptors
#     res[i] = fn(mol)
#   File "D:\DevTools\anaconda3\envs\aho_py310\lib\site-packages\rdkit\Chem\MolSurf.py", line 274, in <lambda>
#     fn = lambda x, y=i: PEOE_VSA_(x, force=0)[y]
# Boost.Python.ArgumentError: Python argument types in
#     None.PEOE_VSA_(NoneType)
# did not match C++ signature:
#     PEOE_VSA_(class RDKit::ROMol mol, class boost::python::api::object bins=[], bool force=False)
# Traceback (most recent call last):
#   File "D:\DevTools\anaconda3\envs\aho_py310\lib\site-packages\rdkit\ML\Descriptors\MoleculeDescriptors.py", line 86, in CalcDescriptors
#     res[i] = fn(mol)
#   File "D:\DevTools\anaconda3\envs\aho_py310\lib\site-packages\rdkit\Chem\MolSurf.py", line 274, in <lambda>
#     fn = lambda x, y=i: PEOE_VSA_(x, force=0)[y]
# Boost.Python.ArgumentError: Python argument types in
#     None.PEOE_VSA_(NoneType)
# did not match C++ signature:
#     PEOE_VSA_(class RDKit::ROMol mol, class boost::python::api::object bins=[], bool force=False)
# Traceback (most recent call last):
#   File "D:\DevTools\anaconda3\envs\aho_py310\lib\site-packages\rdkit\ML\Descriptors\MoleculeDescriptors.py", line 86, in CalcDescriptors
#     res[i] = fn(mol)
#   File "D:\DevTools\anaconda3\envs\aho_py310\lib\site-packages\rdkit\Chem\MolSurf.py", line 274, in <lambda>
#     fn = lambda x, y=i: PEOE_VSA_(x, force=0)[y]
# Boost.Python.ArgumentError: Python argument types in
#     None.PEOE_VSA_(NoneType)
# did not match C++ signature:
#     PEOE_VSA_(class RDKit::ROMol mol, class boost::python::api::object bins=[], bool force=False)
# Traceback (most recent call last):
#   File "D:\DevTools\anaconda3\envs\aho_py310\lib\site-packages\rdkit\ML\Descriptors\MoleculeDescriptors.py", line 86, in CalcDescriptors
#     res[i] = fn(mol)
#   File "D:\DevTools\anaconda3\envs\aho_py310\lib\site-packages\rdkit\Chem\MolSurf.py", line 274, in <lambda>
#     fn = lambda x, y=i: PEOE_VSA_(x, force=0)[y]
# Boost.Python.ArgumentError: Python argument types in
#     None.PEOE_VSA_(NoneType)
# did not match C++ signature:
#     PEOE_VSA_(class RDKit::ROMol mol, class boost::python::api::object bins=[], bool force=False)
# Traceback (most recent call last):
#   File "D:\DevTools\anaconda3\envs\aho_py310\lib\site-packages\rdkit\ML\Descriptors\MoleculeDescriptors.py", line 86, in CalcDescriptors
#     res[i] = fn(mol)
#   File "D:\DevTools\anaconda3\envs\aho_py310\lib\site-packages\rdkit\Chem\MolSurf.py", line 240, in <lambda>
#     fn = lambda x, y=i: SMR_VSA_(x, force=0)[y]
# Boost.Python.ArgumentError: Python argument types in
#     None.SMR_VSA_(NoneType)
# did not match C++ signature:
#     SMR_VSA_(class RDKit::ROMol mol, class boost::python::api::object bins=[], bool force=False)
# Traceback (most recent call last):
#   File "D:\DevTools\anaconda3\envs\aho_py310\lib\site-packages\rdkit\ML\Descriptors\MoleculeDescriptors.py", line 86, in CalcDescriptors
#     res[i] = fn(mol)
#   File "D:\DevTools\anaconda3\envs\aho_py310\lib\site-packages\rdkit\Chem\MolSurf.py", line 250, in <lambda>
#     fn = lambda x, y=i: SMR_VSA_(x, force=0)[y]
# Boost.Python.ArgumentError: Python argument types in
#     None.SMR_VSA_(NoneType)
# did not match C++ signature:
#     SMR_VSA_(class RDKit::ROMol mol, class boost::python::api::object bins=[], bool force=False)
# Traceback (most recent call last):
#   File "D:\DevTools\anaconda3\envs\aho_py310\lib\site-packages\rdkit\ML\Descriptors\MoleculeDescriptors.py", line 86, in CalcDescriptors
#     res[i] = fn(mol)
#   File "D:\DevTools\anaconda3\envs\aho_py310\lib\site-packages\rdkit\Chem\MolSurf.py", line 240, in <lambda>
#     fn = lambda x, y=i: SMR_VSA_(x, force=0)[y]
# Boost.Python.ArgumentError: Python argument types in
#     None.SMR_VSA_(NoneType)
# did not match C++ signature:
#     SMR_VSA_(class RDKit::ROMol mol, class boost::python::api::object bins=[], bool force=False)
# Traceback (most recent call last):
#   File "D:\DevTools\anaconda3\envs\aho_py310\lib\site-packages\rdkit\ML\Descriptors\MoleculeDescriptors.py", line 86, in CalcDescriptors
#     res[i] = fn(mol)
#   File "D:\DevTools\anaconda3\envs\aho_py310\lib\site-packages\rdkit\Chem\MolSurf.py", line 240, in <lambda>
#     fn = lambda x, y=i: SMR_VSA_(x, force=0)[y]
# Boost.Python.ArgumentError: Python argument types in
#     None.SMR_VSA_(NoneType)
# did not match C++ signature:
#     SMR_VSA_(class RDKit::ROMol mol, class boost::python::api::object bins=[], bool force=False)
# Traceback (most recent call last):
#   File "D:\DevTools\anaconda3\envs\aho_py310\lib\site-packages\rdkit\ML\Descriptors\MoleculeDescriptors.py", line 86, in CalcDescriptors
#     res[i] = fn(mol)
#   File "D:\DevTools\anaconda3\envs\aho_py310\lib\site-packages\rdkit\Chem\MolSurf.py", line 240, in <lambda>
#     fn = lambda x, y=i: SMR_VSA_(x, force=0)[y]
# Boost.Python.ArgumentError: Python argument types in
#     None.SMR_VSA_(NoneType)
# did not match C++ signature:
#     SMR_VSA_(class RDKit::ROMol mol, class boost::python::api::object bins=[], bool force=False)
# Traceback (most recent call last):
#   File "D:\DevTools\anaconda3\envs\aho_py310\lib\site-packages\rdkit\ML\Descriptors\MoleculeDescriptors.py", line 86, in CalcDescriptors
#     res[i] = fn(mol)
#   File "D:\DevTools\anaconda3\envs\aho_py310\lib\site-packages\rdkit\Chem\MolSurf.py", line 240, in <lambda>
#     fn = lambda x, y=i: SMR_VSA_(x, force=0)[y]
# Boost.Python.ArgumentError: Python argument types in
#     None.SMR_VSA_(NoneType)
# did not match C++ signature:
#     SMR_VSA_(class RDKit::ROMol mol, class boost::python::api::object bins=[], bool force=False)
# Traceback (most recent call last):
#   File "D:\DevTools\anaconda3\envs\aho_py310\lib\site-packages\rdkit\ML\Descriptors\MoleculeDescriptors.py", line 86, in CalcDescriptors
#     res[i] = fn(mol)
#   File "D:\DevTools\anaconda3\envs\aho_py310\lib\site-packages\rdkit\Chem\MolSurf.py", line 240, in <lambda>
#     fn = lambda x, y=i: SMR_VSA_(x, force=0)[y]
# Boost.Python.ArgumentError: Python argument types in
#     None.SMR_VSA_(NoneType)
# did not match C++ signature:
#     SMR_VSA_(class RDKit::ROMol mol, class boost::python::api::object bins=[], bool force=False)
# Traceback (most recent call last):
#   File "D:\DevTools\anaconda3\envs\aho_py310\lib\site-packages\rdkit\ML\Descriptors\MoleculeDescriptors.py", line 86, in CalcDescriptors
#     res[i] = fn(mol)
#   File "D:\DevTools\anaconda3\envs\aho_py310\lib\site-packages\rdkit\Chem\MolSurf.py", line 240, in <lambda>
#     fn = lambda x, y=i: SMR_VSA_(x, force=0)[y]
# Boost.Python.ArgumentError: Python argument types in
#     None.SMR_VSA_(NoneType)
# did not match C++ signature:
#     SMR_VSA_(class RDKit::ROMol mol, class boost::python::api::object bins=[], bool force=False)
# Traceback (most recent call last):
#   File "D:\DevTools\anaconda3\envs\aho_py310\lib\site-packages\rdkit\ML\Descriptors\MoleculeDescriptors.py", line 86, in CalcDescriptors
#     res[i] = fn(mol)
#   File "D:\DevTools\anaconda3\envs\aho_py310\lib\site-packages\rdkit\Chem\MolSurf.py", line 240, in <lambda>
#     fn = lambda x, y=i: SMR_VSA_(x, force=0)[y]
# Boost.Python.ArgumentError: Python argument types in
#     None.SMR_VSA_(NoneType)
# did not match C++ signature:
#     SMR_VSA_(class RDKit::ROMol mol, class boost::python::api::object bins=[], bool force=False)
# Traceback (most recent call last):
#   File "D:\DevTools\anaconda3\envs\aho_py310\lib\site-packages\rdkit\ML\Descriptors\MoleculeDescriptors.py", line 86, in CalcDescriptors
#     res[i] = fn(mol)
#   File "D:\DevTools\anaconda3\envs\aho_py310\lib\site-packages\rdkit\Chem\MolSurf.py", line 240, in <lambda>
#     fn = lambda x, y=i: SMR_VSA_(x, force=0)[y]
# Boost.Python.ArgumentError: Python argument types in
#     None.SMR_VSA_(NoneType)
# did not match C++ signature:
#     SMR_VSA_(class RDKit::ROMol mol, class boost::python::api::object bins=[], bool force=False)
# Traceback (most recent call last):
#   File "D:\DevTools\anaconda3\envs\aho_py310\lib\site-packages\rdkit\ML\Descriptors\MoleculeDescriptors.py", line 86, in CalcDescriptors
#     res[i] = fn(mol)
#   File "D:\DevTools\anaconda3\envs\aho_py310\lib\site-packages\rdkit\Chem\MolSurf.py", line 257, in <lambda>
#     fn = lambda x, y=i: SlogP_VSA_(x, force=0)[y]
# Boost.Python.ArgumentError: Python argument types in
#     None.SlogP_VSA_(NoneType)
# did not match C++ signature:
#     SlogP_VSA_(class RDKit::ROMol mol, class boost::python::api::object bins=[], bool force=False)
# Traceback (most recent call last):
#   File "D:\DevTools\anaconda3\envs\aho_py310\lib\site-packages\rdkit\ML\Descriptors\MoleculeDescriptors.py", line 86, in CalcDescriptors
#     res[i] = fn(mol)
#   File "D:\DevTools\anaconda3\envs\aho_py310\lib\site-packages\rdkit\Chem\MolSurf.py", line 257, in <lambda>
#     fn = lambda x, y=i: SlogP_VSA_(x, force=0)[y]
# Boost.Python.ArgumentError: Python argument types in
#     None.SlogP_VSA_(NoneType)
# did not match C++ signature:
#     SlogP_VSA_(class RDKit::ROMol mol, class boost::python::api::object bins=[], bool force=False)
# Traceback (most recent call last):
#   File "D:\DevTools\anaconda3\envs\aho_py310\lib\site-packages\rdkit\ML\Descriptors\MoleculeDescriptors.py", line 86, in CalcDescriptors
#     res[i] = fn(mol)
#   File "D:\DevTools\anaconda3\envs\aho_py310\lib\site-packages\rdkit\Chem\MolSurf.py", line 257, in <lambda>
#     fn = lambda x, y=i: SlogP_VSA_(x, force=0)[y]
# Boost.Python.ArgumentError: Python argument types in
#     None.SlogP_VSA_(NoneType)
# did not match C++ signature:
#     SlogP_VSA_(class RDKit::ROMol mol, class boost::python::api::object bins=[], bool force=False)
# Traceback (most recent call last):
#   File "D:\DevTools\anaconda3\envs\aho_py310\lib\site-packages\rdkit\ML\Descriptors\MoleculeDescriptors.py", line 86, in CalcDescriptors
#     res[i] = fn(mol)
#   File "D:\DevTools\anaconda3\envs\aho_py310\lib\site-packages\rdkit\Chem\MolSurf.py", line 267, in <lambda>
#     fn = lambda x, y=i: SlogP_VSA_(x, force=0)[y]
# Boost.Python.ArgumentError: Python argument types in
#     None.SlogP_VSA_(NoneType)
# did not match C++ signature:
#     SlogP_VSA_(class RDKit::ROMol mol, class boost::python::api::object bins=[], bool force=False)
# Traceback (most recent call last):
#   File "D:\DevTools\anaconda3\envs\aho_py310\lib\site-packages\rdkit\ML\Descriptors\MoleculeDescriptors.py", line 86, in CalcDescriptors
#     res[i] = fn(mol)
#   File "D:\DevTools\anaconda3\envs\aho_py310\lib\site-packages\rdkit\Chem\MolSurf.py", line 257, in <lambda>
#     fn = lambda x, y=i: SlogP_VSA_(x, force=0)[y]
# Boost.Python.ArgumentError: Python argument types in
#     None.SlogP_VSA_(NoneType)
# did not match C++ signature:
#     SlogP_VSA_(class RDKit::ROMol mol, class boost::python::api::object bins=[], bool force=False)
# Traceback (most recent call last):
#   File "D:\DevTools\anaconda3\envs\aho_py310\lib\site-packages\rdkit\ML\Descriptors\MoleculeDescriptors.py", line 86, in CalcDescriptors
#     res[i] = fn(mol)
#   File "D:\DevTools\anaconda3\envs\aho_py310\lib\site-packages\rdkit\Chem\MolSurf.py", line 257, in <lambda>
#     fn = lambda x, y=i: SlogP_VSA_(x, force=0)[y]
# Boost.Python.ArgumentError: Python argument types in
#     None.SlogP_VSA_(NoneType)
# did not match C++ signature:
#     SlogP_VSA_(class RDKit::ROMol mol, class boost::python::api::object bins=[], bool force=False)
# Traceback (most recent call last):
#   File "D:\DevTools\anaconda3\envs\aho_py310\lib\site-packages\rdkit\ML\Descriptors\MoleculeDescriptors.py", line 86, in CalcDescriptors
#     res[i] = fn(mol)
#   File "D:\DevTools\anaconda3\envs\aho_py310\lib\site-packages\rdkit\Chem\MolSurf.py", line 257, in <lambda>
#     fn = lambda x, y=i: SlogP_VSA_(x, force=0)[y]
# Boost.Python.ArgumentError: Python argument types in
#     None.SlogP_VSA_(NoneType)
# did not match C++ signature:
#     SlogP_VSA_(class RDKit::ROMol mol, class boost::python::api::object bins=[], bool force=False)
# Traceback (most recent call last):
#   File "D:\DevTools\anaconda3\envs\aho_py310\lib\site-packages\rdkit\ML\Descriptors\MoleculeDescriptors.py", line 86, in CalcDescriptors
#     res[i] = fn(mol)
#   File "D:\DevTools\anaconda3\envs\aho_py310\lib\site-packages\rdkit\Chem\MolSurf.py", line 257, in <lambda>
#     fn = lambda x, y=i: SlogP_VSA_(x, force=0)[y]
# Boost.Python.ArgumentError: Python argument types in
#     None.SlogP_VSA_(NoneType)
# did not match C++ signature:
#     SlogP_VSA_(class RDKit::ROMol mol, class boost::python::api::object bins=[], bool force=False)
# Traceback (most recent call last):
#   File "D:\DevTools\anaconda3\envs\aho_py310\lib\site-packages\rdkit\ML\Descriptors\MoleculeDescriptors.py", line 86, in CalcDescriptors
#     res[i] = fn(mol)
#   File "D:\DevTools\anaconda3\envs\aho_py310\lib\site-packages\rdkit\Chem\MolSurf.py", line 257, in <lambda>
#     fn = lambda x, y=i: SlogP_VSA_(x, force=0)[y]
# Boost.Python.ArgumentError: Python argument types in
#     None.SlogP_VSA_(NoneType)
# did not match C++ signature:
#     SlogP_VSA_(class RDKit::ROMol mol, class boost::python::api::object bins=[], bool force=False)
# Traceback (most recent call last):
#   File "D:\DevTools\anaconda3\envs\aho_py310\lib\site-packages\rdkit\ML\Descriptors\MoleculeDescriptors.py", line 86, in CalcDescriptors
#     res[i] = fn(mol)
#   File "D:\DevTools\anaconda3\envs\aho_py310\lib\site-packages\rdkit\Chem\MolSurf.py", line 257, in <lambda>
#     fn = lambda x, y=i: SlogP_VSA_(x, force=0)[y]
# Boost.Python.ArgumentError: Python argument types in
#     None.SlogP_VSA_(NoneType)
# did not match C++ signature:
#     SlogP_VSA_(class RDKit::ROMol mol, class boost::python::api::object bins=[], bool force=False)
# Traceback (most recent call last):
#   File "D:\DevTools\anaconda3\envs\aho_py310\lib\site-packages\rdkit\ML\Descriptors\MoleculeDescriptors.py", line 86, in CalcDescriptors
#     res[i] = fn(mol)
#   File "D:\DevTools\anaconda3\envs\aho_py310\lib\site-packages\rdkit\Chem\MolSurf.py", line 257, in <lambda>
#     fn = lambda x, y=i: SlogP_VSA_(x, force=0)[y]
# Boost.Python.ArgumentError: Python argument types in
#     None.SlogP_VSA_(NoneType)
# did not match C++ signature:
#     SlogP_VSA_(class RDKit::ROMol mol, class boost::python::api::object bins=[], bool force=False)
# Traceback (most recent call last):
#   File "D:\DevTools\anaconda3\envs\aho_py310\lib\site-packages\rdkit\ML\Descriptors\MoleculeDescriptors.py", line 86, in CalcDescriptors
#     res[i] = fn(mol)
#   File "D:\DevTools\anaconda3\envs\aho_py310\lib\site-packages\rdkit\Chem\MolSurf.py", line 257, in <lambda>
#     fn = lambda x, y=i: SlogP_VSA_(x, force=0)[y]
# Boost.Python.ArgumentError: Python argument types in
#     None.SlogP_VSA_(NoneType)
# did not match C++ signature:
#     SlogP_VSA_(class RDKit::ROMol mol, class boost::python::api::object bins=[], bool force=False)
# Traceback (most recent call last):
#   File "D:\DevTools\anaconda3\envs\aho_py310\lib\site-packages\rdkit\ML\Descriptors\MoleculeDescriptors.py", line 86, in CalcDescriptors
#     res[i] = fn(mol)
#   File "D:\DevTools\anaconda3\envs\aho_py310\lib\site-packages\rdkit\Chem\MolSurf.py", line 480, in <lambda>
#     TPSA = lambda *x, **y: rdMolDescriptors.CalcTPSA(*x, **y)
# Boost.Python.ArgumentError: Python argument types in
#     None.CalcTPSA(NoneType)
# did not match C++ signature:
#     CalcTPSA(class RDKit::ROMol mol, bool force=False, bool includeSandP=False)
# Traceback (most recent call last):
#   File "D:\DevTools\anaconda3\envs\aho_py310\lib\site-packages\rdkit\ML\Descriptors\MoleculeDescriptors.py", line 86, in CalcDescriptors
#     res[i] = fn(mol)
#   File "D:\DevTools\anaconda3\envs\aho_py310\lib\site-packages\rdkit\Chem\EState\EState_VSA.py", line 109, in EState_VSA_bin
#     return EState_VSA_(mol, force=False)[nbin]
#   File "D:\DevTools\anaconda3\envs\aho_py310\lib\site-packages\rdkit\Chem\EState\EState_VSA.py", line 71, in EState_VSA_
#     propContribs = EStateIndices_(mol, force=force)
#   File "D:\DevTools\anaconda3\envs\aho_py310\lib\site-packages\rdkit\Chem\EState\EState.py", line 45, in EStateIndices
#     nAtoms = mol.GetNumAtoms()
# AttributeError: 'NoneType' object has no attribute 'GetNumAtoms'
# Traceback (most recent call last):
#   File "D:\DevTools\anaconda3\envs\aho_py310\lib\site-packages\rdkit\ML\Descriptors\MoleculeDescriptors.py", line 86, in CalcDescriptors
#     res[i] = fn(mol)
#   File "D:\DevTools\anaconda3\envs\aho_py310\lib\site-packages\rdkit\Chem\EState\EState_VSA.py", line 109, in EState_VSA_bin
#     return EState_VSA_(mol, force=False)[nbin]
#   File "D:\DevTools\anaconda3\envs\aho_py310\lib\site-packages\rdkit\Chem\EState\EState_VSA.py", line 71, in EState_VSA_
#     propContribs = EStateIndices_(mol, force=force)
#   File "D:\DevTools\anaconda3\envs\aho_py310\lib\site-packages\rdkit\Chem\EState\EState.py", line 45, in EStateIndices
#     nAtoms = mol.GetNumAtoms()
# AttributeError: 'NoneType' object has no attribute 'GetNumAtoms'
# Traceback (most recent call last):
#   File "D:\DevTools\anaconda3\envs\aho_py310\lib\site-packages\rdkit\ML\Descriptors\MoleculeDescriptors.py", line 86, in CalcDescriptors
#     res[i] = fn(mol)
#   File "D:\DevTools\anaconda3\envs\aho_py310\lib\site-packages\rdkit\Chem\EState\EState_VSA.py", line 109, in EState_VSA_bin
#     return EState_VSA_(mol, force=False)[nbin]
# ...
# AttributeError: 'NoneType' object has no attribute 'GetSubstructMatches'
# Traceback (most recent call last):
#   File "D:\DevTools\anaconda3\envs\aho_py310\lib\site-packages\rdkit\ML\Descriptors\MoleculeDescriptors.py", line 86, in CalcDescriptors
#     res[i] = fn(mol)
#   File "D:\DevTools\anaconda3\envs\aho_py310\lib\site-packages\rdkit\Chem\Fragments.py", line 44, in <lambda>
#     fn = lambda mol, countUnique=True, pattern=patt: _CountMatches(
#   File "D:\DevTools\anaconda3\envs\aho_py310\lib\site-packages\rdkit\Chem\Fragments.py", line 22, in _CountMatches
#     return len(mol.GetSubstructMatches(patt, uniquify=unique))
# AttributeError: 'NoneType' object has no attribute 'GetSubstructMatches'
# Traceback (most recent call last):
#   File "D:\DevTools\anaconda3\envs\aho_py310\lib\site-packages\rdkit\ML\Descriptors\MoleculeDescriptors.py", line 86, in CalcDescriptors
#     res[i] = fn(mol)
#   File "D:\DevTools\anaconda3\envs\aho_py310\lib\site-packages\rdkit\Chem\Fragments.py", line 44, in <lambda>
#     fn = lambda mol, countUnique=True, pattern=patt: _CountMatches(
#   File "D:\DevTools\anaconda3\envs\aho_py310\lib\site-packages\rdkit\Chem\Fragments.py", line 22, in _CountMatches
#     return len(mol.GetSubstructMatches(patt, uniquify=unique))
# AttributeError: 'NoneType' object has no attribute 'GetSubstructMatches'
# Traceback (most recent call last):
#   File "D:\DevTools\anaconda3\envs\aho_py310\lib\site-packages\rdkit\ML\Descriptors\MoleculeDescriptors.py", line 86, in CalcDescriptors
#     res[i] = fn(mol)
#   File "D:\DevTools\anaconda3\envs\aho_py310\lib\site-packages\rdkit\Chem\Fragments.py", line 44, in <lambda>
#     fn = lambda mol, countUnique=True, pattern=patt: _CountMatches(
#   File "D:\DevTools\anaconda3\envs\aho_py310\lib\site-packages\rdkit\Chem\Fragments.py", line 22, in _CountMatches
#     return len(mol.GetSubstructMatches(patt, uniquify=unique))
# AttributeError: 'NoneType' object has no attribute 'GetSubstructMatches'
# Traceback (most recent call last):
#   File "D:\DevTools\anaconda3\envs\aho_py310\lib\site-packages\rdkit\ML\Descriptors\MoleculeDescriptors.py", line 86, in CalcDescriptors
#     res[i] = fn(mol)
#   File "D:\DevTools\anaconda3\envs\aho_py310\lib\site-packages\rdkit\Chem\Fragments.py", line 44, in <lambda>
#     fn = lambda mol, countUnique=True, pattern=patt: _CountMatches(
#   File "D:\DevTools\anaconda3\envs\aho_py310\lib\site-packages\rdkit\Chem\Fragments.py", line 22, in _CountMatches
#     return len(mol.GetSubstructMatches(patt, uniquify=unique))
# AttributeError: 'NoneType' object has no attribute 'GetSubstructMatches'
# Traceback (most recent call last):
#   File "D:\DevTools\anaconda3\envs\aho_py310\lib\site-packages\rdkit\ML\Descriptors\MoleculeDescriptors.py", line 86, in CalcDescriptors
#     res[i] = fn(mol)
#   File "D:\DevTools\anaconda3\envs\aho_py310\lib\site-packages\rdkit\Chem\Fragments.py", line 44, in <lambda>
#     fn = lambda mol, countUnique=True, pattern=patt: _CountMatches(
#   File "D:\DevTools\anaconda3\envs\aho_py310\lib\site-packages\rdkit\Chem\Fragments.py", line 22, in _CountMatches
#     return len(mol.GetSubstructMatches(patt, uniquify=unique))
# AttributeError: 'NoneType' object has no attribute 'GetSubstructMatches'
# Traceback (most recent call last):
#   File "D:\DevTools\anaconda3\envs\aho_py310\lib\site-packages\rdkit\ML\Descriptors\MoleculeDescriptors.py", line 86, in CalcDescriptors
#     res[i] = fn(mol)
#   File "D:\DevTools\anaconda3\envs\aho_py310\lib\site-packages\rdkit\Chem\Fragments.py", line 44, in <lambda>
#     fn = lambda mol, countUnique=True, pattern=patt: _CountMatches(
#   File "D:\DevTools\anaconda3\envs\aho_py310\lib\site-packages\rdkit\Chem\Fragments.py", line 22, in _CountMatches
#     return len(mol.GetSubstructMatches(patt, uniquify=unique))
# AttributeError: 'NoneType' object has no attribute 'GetSubstructMatches'
# Traceback (most recent call last):
#   File "D:\DevTools\anaconda3\envs\aho_py310\lib\site-packages\rdkit\ML\Descriptors\MoleculeDescriptors.py", line 86, in CalcDescriptors
#     res[i] = fn(mol)
#   File "D:\DevTools\anaconda3\envs\aho_py310\lib\site-packages\rdkit\Chem\Fragments.py", line 44, in <lambda>
#     fn = lambda mol, countUnique=True, pattern=patt: _CountMatches(
#   File "D:\DevTools\anaconda3\envs\aho_py310\lib\site-packages\rdkit\Chem\Fragments.py", line 22, in _CountMatches
#     return len(mol.GetSubstructMatches(patt, uniquify=unique))
# AttributeError: 'NoneType' object has no attribute 'GetSubstructMatches'
# Traceback (most recent call last):
#   File "D:\DevTools\anaconda3\envs\aho_py310\lib\site-packages\rdkit\ML\Descriptors\MoleculeDescriptors.py", line 86, in CalcDescriptors
#     res[i] = fn(mol)
#   File "D:\DevTools\anaconda3\envs\aho_py310\lib\site-packages\rdkit\Chem\Fragments.py", line 44, in <lambda>
#     fn = lambda mol, countUnique=True, pattern=patt: _CountMatches(
#   File "D:\DevTools\anaconda3\envs\aho_py310\lib\site-packages\rdkit\Chem\Fragments.py", line 22, in _CountMatches
#     return len(mol.GetSubstructMatches(patt, uniquify=unique))
# AttributeError: 'NoneType' object has no attribute 'GetSubstructMatches'
# Traceback (most recent call last):
#   File "D:\DevTools\anaconda3\envs\aho_py310\lib\site-packages\rdkit\ML\Descriptors\MoleculeDescriptors.py", line 86, in CalcDescriptors
#     res[i] = fn(mol)
#   File "D:\DevTools\anaconda3\envs\aho_py310\lib\site-packages\rdkit\Chem\Fragments.py", line 44, in <lambda>
#     fn = lambda mol, countUnique=True, pattern=patt: _CountMatches(
#   File "D:\DevTools\anaconda3\envs\aho_py310\lib\site-packages\rdkit\Chem\Fragments.py", line 22, in _CountMatches
#     return len(mol.GetSubstructMatches(patt, uniquify=unique))
# AttributeError: 'NoneType' object has no attribute 'GetSubstructMatches'
# Traceback (most recent call last):
#   File "D:\DevTools\anaconda3\envs\aho_py310\lib\site-packages\rdkit\ML\Descriptors\MoleculeDescriptors.py", line 86, in CalcDescriptors
#     res[i] = fn(mol)
#   File "D:\DevTools\anaconda3\envs\aho_py310\lib\site-packages\rdkit\Chem\Fragments.py", line 44, in <lambda>
#     fn = lambda mol, countUnique=True, pattern=patt: _CountMatches(
#   File "D:\DevTools\anaconda3\envs\aho_py310\lib\site-packages\rdkit\Chem\Fragments.py", line 22, in _CountMatches
#     return len(mol.GetSubstructMatches(patt, uniquify=unique))
# AttributeError: 'NoneType' object has no attribute 'GetSubstructMatches'
# Traceback (most recent call last):
#   File "D:\DevTools\anaconda3\envs\aho_py310\lib\site-packages\rdkit\ML\Descriptors\MoleculeDescriptors.py", line 86, in CalcDescriptors
#     res[i] = fn(mol)
#   File "D:\DevTools\anaconda3\envs\aho_py310\lib\site-packages\rdkit\Chem\Fragments.py", line 44, in <lambda>
#     fn = lambda mol, countUnique=True, pattern=patt: _CountMatches(
#   File "D:\DevTools\anaconda3\envs\aho_py310\lib\site-packages\rdkit\Chem\Fragments.py", line 22, in _CountMatches
#     return len(mol.GetSubstructMatches(patt, uniquify=unique))
# AttributeError: 'NoneType' object has no attribute 'GetSubstructMatches'
# Traceback (most recent call last):
#   File "D:\DevTools\anaconda3\envs\aho_py310\lib\site-packages\rdkit\ML\Descriptors\MoleculeDescriptors.py", line 86, in CalcDescriptors
#     res[i] = fn(mol)
#   File "D:\DevTools\anaconda3\envs\aho_py310\lib\site-packages\rdkit\Chem\Fragments.py", line 44, in <lambda>
#     fn = lambda mol, countUnique=True, pattern=patt: _CountMatches(
#   File "D:\DevTools\anaconda3\envs\aho_py310\lib\site-packages\rdkit\Chem\Fragments.py", line 22, in _CountMatches
#     return len(mol.GetSubstructMatches(patt, uniquify=unique))
# AttributeError: 'NoneType' object has no attribute 'GetSubstructMatches'
# Traceback (most recent call last):
#   File "D:\DevTools\anaconda3\envs\aho_py310\lib\site-packages\rdkit\ML\Descriptors\MoleculeDescriptors.py", line 86, in CalcDescriptors
#     res[i] = fn(mol)
#   File "D:\DevTools\anaconda3\envs\aho_py310\lib\site-packages\rdkit\Chem\Fragments.py", line 44, in <lambda>
#     fn = lambda mol, countUnique=True, pattern=patt: _CountMatches(
#   File "D:\DevTools\anaconda3\envs\aho_py310\lib\site-packages\rdkit\Chem\Fragments.py", line 22, in _CountMatches
#     return len(mol.GetSubstructMatches(patt, uniquify=unique))
# AttributeError: 'NoneType' object has no attribute 'GetSubstructMatches'
# Traceback (most recent call last):
#   File "D:\DevTools\anaconda3\envs\aho_py310\lib\site-packages\rdkit\ML\Descriptors\MoleculeDescriptors.py", line 86, in CalcDescriptors
#     res[i] = fn(mol)
#   File "D:\DevTools\anaconda3\envs\aho_py310\lib\site-packages\rdkit\Chem\Fragments.py", line 44, in <lambda>
#     fn = lambda mol, countUnique=True, pattern=patt: _CountMatches(
#   File "D:\DevTools\anaconda3\envs\aho_py310\lib\site-packages\rdkit\Chem\Fragments.py", line 22, in _CountMatches
#     return len(mol.GetSubstructMatches(patt, uniquify=unique))
# AttributeError: 'NoneType' object has no attribute 'GetSubstructMatches'
# Traceback (most recent call last):
#   File "D:\DevTools\anaconda3\envs\aho_py310\lib\site-packages\rdkit\ML\Descriptors\MoleculeDescriptors.py", line 86, in CalcDescriptors
#     res[i] = fn(mol)
#   File "D:\DevTools\anaconda3\envs\aho_py310\lib\site-packages\rdkit\Chem\Fragments.py", line 44, in <lambda>
#     fn = lambda mol, countUnique=True, pattern=patt: _CountMatches(
#   File "D:\DevTools\anaconda3\envs\aho_py310\lib\site-packages\rdkit\Chem\Fragments.py", line 22, in _CountMatches
#     return len(mol.GetSubstructMatches(patt, uniquify=unique))
# AttributeError: 'NoneType' object has no attribute 'GetSubstructMatches'
# Traceback (most recent call last):
#   File "D:\DevTools\anaconda3\envs\aho_py310\lib\site-packages\rdkit\ML\Descriptors\MoleculeDescriptors.py", line 86, in CalcDescriptors
#     res[i] = fn(mol)
#   File "D:\DevTools\anaconda3\envs\aho_py310\lib\site-packages\rdkit\Chem\Fragments.py", line 44, in <lambda>
#     fn = lambda mol, countUnique=True, pattern=patt: _CountMatches(
#   File "D:\DevTools\anaconda3\envs\aho_py310\lib\site-packages\rdkit\Chem\Fragments.py", line 22, in _CountMatches
#     return len(mol.GetSubstructMatches(patt, uniquify=unique))
# AttributeError: 'NoneType' object has no attribute 'GetSubstructMatches'
# Traceback (most recent call last):
#   File "D:\DevTools\anaconda3\envs\aho_py310\lib\site-packages\rdkit\ML\Descriptors\MoleculeDescriptors.py", line 86, in CalcDescriptors
#     res[i] = fn(mol)
#   File "D:\DevTools\anaconda3\envs\aho_py310\lib\site-packages\rdkit\Chem\Fragments.py", line 44, in <lambda>
#     fn = lambda mol, countUnique=True, pattern=patt: _CountMatches(
#   File "D:\DevTools\anaconda3\envs\aho_py310\lib\site-packages\rdkit\Chem\Fragments.py", line 22, in _CountMatches
#     return len(mol.GetSubstructMatches(patt, uniquify=unique))
# AttributeError: 'NoneType' object has no attribute 'GetSubstructMatches'
# Traceback (most recent call last):
#   File "D:\DevTools\anaconda3\envs\aho_py310\lib\site-packages\rdkit\ML\Descriptors\MoleculeDescriptors.py", line 86, in CalcDescriptors
#     res[i] = fn(mol)
#   File "D:\DevTools\anaconda3\envs\aho_py310\lib\site-packages\rdkit\Chem\Fragments.py", line 44, in <lambda>
#     fn = lambda mol, countUnique=True, pattern=patt: _CountMatches(
#   File "D:\DevTools\anaconda3\envs\aho_py310\lib\site-packages\rdkit\Chem\Fragments.py", line 22, in _CountMatches
#     return len(mol.GetSubstructMatches(patt, uniquify=unique))
# AttributeError: 'NoneType' object has no attribute 'GetSubstructMatches'
# Traceback (most recent call last):
#   File "D:\DevTools\anaconda3\envs\aho_py310\lib\site-packages\rdkit\ML\Descriptors\MoleculeDescriptors.py", line 86, in CalcDescriptors
#     res[i] = fn(mol)
#   File "D:\DevTools\anaconda3\envs\aho_py310\lib\site-packages\rdkit\Chem\Fragments.py", line 44, in <lambda>
#     fn = lambda mol, countUnique=True, pattern=patt: _CountMatches(
#   File "D:\DevTools\anaconda3\envs\aho_py310\lib\site-packages\rdkit\Chem\Fragments.py", line 22, in _CountMatches
#     return len(mol.GetSubstructMatches(patt, uniquify=unique))
# AttributeError: 'NoneType' object has no attribute 'GetSubstructMatches'
# Traceback (most recent call last):
#   File "D:\DevTools\anaconda3\envs\aho_py310\lib\site-packages\rdkit\ML\Descriptors\MoleculeDescriptors.py", line 86, in CalcDescriptors
#     res[i] = fn(mol)
#   File "D:\DevTools\anaconda3\envs\aho_py310\lib\site-packages\rdkit\Chem\Fragments.py", line 44, in <lambda>
#     fn = lambda mol, countUnique=True, pattern=patt: _CountMatches(
#   File "D:\DevTools\anaconda3\envs\aho_py310\lib\site-packages\rdkit\Chem\Fragments.py", line 22, in _CountMatches
#     return len(mol.GetSubstructMatches(patt, uniquify=unique))
# AttributeError: 'NoneType' object has no attribute 'GetSubstructMatches'
# Traceback (most recent call last):
#   File "D:\DevTools\anaconda3\envs\aho_py310\lib\site-packages\rdkit\ML\Descriptors\MoleculeDescriptors.py", line 86, in CalcDescriptors
#     res[i] = fn(mol)
#   File "D:\DevTools\anaconda3\envs\aho_py310\lib\site-packages\rdkit\Chem\Fragments.py", line 44, in <lambda>
#     fn = lambda mol, countUnique=True, pattern=patt: _CountMatches(
#   File "D:\DevTools\anaconda3\envs\aho_py310\lib\site-packages\rdkit\Chem\Fragments.py", line 22, in _CountMatches
#     return len(mol.GetSubstructMatches(patt, uniquify=unique))
# AttributeError: 'NoneType' object has no attribute 'GetSubstructMatches'
# Traceback (most recent call last):
#   File "D:\DevTools\anaconda3\envs\aho_py310\lib\site-packages\rdkit\ML\Descriptors\MoleculeDescriptors.py", line 86, in CalcDescriptors
#     res[i] = fn(mol)
#   File "D:\DevTools\anaconda3\envs\aho_py310\lib\site-packages\rdkit\Chem\Fragments.py", line 44, in <lambda>
#     fn = lambda mol, countUnique=True, pattern=patt: _CountMatches(
#   File "D:\DevTools\anaconda3\envs\aho_py310\lib\site-packages\rdkit\Chem\Fragments.py", line 22, in _CountMatches
#     return len(mol.GetSubstructMatches(patt, uniquify=unique))
# AttributeError: 'NoneType' object has no attribute 'GetSubstructMatches'
# ---------------------------------------------------------------------------
# ArgumentError                             Traceback (most recent call last)
# Cell In[5], line 5
#       3 radius = 4
#       4 nBits = 2048
# ----> 5 mf_desc_map = gen2d.calc_mf_desc(radius,nBits=nBits,useChirality=True)
#
# File z:\Codefield\Antigravity\8.8-Antigravity-Github\AHO\examples\gendesc.py:132, in generate2Ddesc.calc_mf_desc(self, radius, nBits, useChirality)
#     121 def calc_mf_desc(self,radius=4,nBits=2048,useChirality=True):
#     122     '''
#     123
#     124
#    (...)
#     129
#     130     '''
# --> 132     mf_desc_map = {self.smi_set[i]:self.getmorganfp(self.mol_set[i],
#     133     radius=radius,nBits=nBits,useChirality=useChirality) for i in range(len(self.smi_set))}
#     134     return mf_desc_map
#
# File z:\Codefield\Antigravity\8.8-Antigravity-Github\AHO\examples\gendesc.py:132, in <dictcomp>(.0)
#     121 def calc_mf_desc(self,radius=4,nBits=2048,useChirality=True):
#     122     '''
#     123
#     124
#    (...)
#     129
#     130     '''
# --> 132     mf_desc_map = {self.smi_set[i]:self.getmorganfp(self.mol_set[i],
#     133     radius=radius,nBits=nBits,useChirality=useChirality) for i in range(len(self.smi_set))}
#     134     return mf_desc_map
#
# File z:\Codefield\Antigravity\8.8-Antigravity-Github\AHO\examples\gendesc.py:88, in generate2Ddesc.getmorganfp(self, mol, radius, nBits, useChirality)
#      74 def getmorganfp(self,mol,radius=4,nBits=2048,useChirality=True):
#      75     '''
#      76
#      77     Parameters
#    (...)
#      86
#      87     '''
# ---> 88     fp = Chem.rdMolDescriptors.GetMorganFingerprintAsBitVect(mol,radius=radius,nBits=nBits,useChirality=useChirality)
#      89     return np.array(list(map(eval,list(fp.ToBitString()))))
#
# ArgumentError: Python argument types in
#     None.GetMorganFingerprintAsBitVect(NoneType)
# did not match C++ signature:
#     GetMorganFingerprintAsBitVect(class RDKit::ROMol mol, unsigned int radius, unsigned int nBits=2048, class boost::python::api::object invariants=[], class boost::python::api::object fromAtoms=[], bool useChirality=False, bool useBondTypes=True, bool useFeatures=False, class boost::python::api::object bitInfo=None, bool includeRedundantEnvironments=False)

# %%
gen3d = generate3Ddesc('./data/geoms_demo/')
### ACSF Parameters ###
rcut=6.0
g2_params=[[1, 1], [1, 2], [1, 3]]
g4_params=[[1, 1, 1], [1, 2, 1], [1, 1, -1], [1, 2, -1]]
acsf_desc_map = gen3d.calc_acsf_desc(rcut,g2_params,g4_params)
### SOAP Parameters ###
rcut = 6.0
nmax = 4
lmax = 3
soap_desc_map = gen3d.calc_soap_desc(rcut,nmax,lmax)
### LMBTR Parameters ###
k2={
        "geometry": {"function": "inverse_distance"},
        "grid": {"min": 0, "max": 1, "n": 10, "sigma": 0.1},
        "weighting": {"function": "exponential", "scale": 0.5, "cutoff": 1e-3},
    }
k3={
        "geometry": {"function": "cosine"},
        "grid": {"min": -1, "max": 1, "n": 10, "sigma": 0.1},
        "weighting": {"function": "exponential", "scale": 0.5, "cutoff": 1e-3},
    }
lmbtr_desc_map = gen3d.calc_lmbtr_desc(k2,k3)
### MBTR Parameters ###
k1={
        "geometry": {"function": "atomic_number"},
        "grid": {"min": 0, "max": 8, "n": 10, "sigma": 0.1},
    }
k2={
        "geometry": {"function": "inverse_distance"},
        "grid": {"min": 0, "max": 4, "n": 10, "sigma": 0.1},
        "weighting": {"function": "exponential", "scale": 0.5, "cutoff": 1e-3},
    }
k3={
        "geometry": {"function": "cosine"},
        "grid": {"min": -1, "max": 4, "n": 10, "sigma": 0.1},
        "weighting": {"function": "exponential", "scale": 0.5, "cutoff": 1e-3},
    }
mbtr_desc_map  = gen3d.calc_mbtr_desc(k1,k2,k3)

# %% [markdown]
# descriptor map demonstration

# %%
print('SMILES:\n %s'%re_smi[0])
print('Top 50 vector of MBTR:')
print(mbtr_desc_map[re_smi[0]][:50])

# %% [markdown]
# # Generate reaction descritor

# %% [markdown]
# In this tutorial, we just generate MBTR+MF reaction descriptor for demonstration

# %%
re_desc_1,re_desc_2 = np.array([mbtr_desc_map[tmp_smi] for tmp_smi in re_smi]),\
                      np.array([mf_desc_map[tmp_smi] for tmp_smi in re_smi])
pr_desc_1,pr_desc_2 = np.array([mbtr_desc_map[tmp_smi] for tmp_smi in pr_smi]),\
                      np.array([mf_desc_map[tmp_smi] for tmp_smi in pr_smi])
sol_desc_1,sol_desc_2 = np.array([mbtr_desc_map[tmp_smi] for tmp_smi in sol_smi]),\
                      np.array([mf_desc_map[tmp_smi] for tmp_smi in sol_smi])
cat_desc_1,cat_desc_2 = np.array([mbtr_desc_map[tmp_smi] for tmp_smi in cat_smi]),\
                      np.array([mf_desc_map[tmp_smi] for tmp_smi in cat_smi])
react_desc = np.concatenate([re_desc_1,re_desc_2,pr_desc_1,pr_desc_2,
                             sol_desc_1,sol_desc_2,cat_desc_1,cat_desc_2,press,temp,s_c],axis=1)
react_desc = maxminscale(process_desc(react_desc)) ### Use "process_desc" function to drop "NaN" value
                                                   ### Use "maxminscale" function to standard descriptor

# %%
react_desc.shape
